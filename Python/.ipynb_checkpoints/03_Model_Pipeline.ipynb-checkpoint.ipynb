# %%
import pandas as pd
import numpy as np
import joblib

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error

# %%
df = pd.read_csv("../Data/Clean_Flight_Data.csv")

df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#   Journey_Month Journey_Day  Departure_Hour
# 0         March      Sunday              22
# 1           May   Wednesday               5
# 2          June      Sunday               9
# 3           May      Sunday              18
# 4         March      Friday              16

# %%
df.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price', 'Journey_Month', 'Journey_Day',
#        'Departure_Hour'],
#       dtype='object')

# %%
data = pd.read_csv("../Data/Clean_Flight_Data.csv")

data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#   Journey_Month Journey_Day  Departure_Hour
# 0         March      Sunday              22
# 1           May   Wednesday               5
# 2          June      Sunday               9
# 3           May      Sunday              18
# 4         March      Friday              16

# %%
data.dtypes
# Out:
# Airline            object
# Date_of_Journey    object
# Source             object
# Destination        object
# Route              object
# Dep_Time           object
# Arrival_Time       object
# Duration           object
# Total_Stops        object
# Additional_Info    object
# Price               int64
# Journey_Month      object
# Journey_Day        object
# Departure_Hour      int64
# dtype: object

# %%
data = df.copy()

# Convert journey date
data["Date_of_Journey"] = pd.to_datetime(data["Date_of_Journey"])

# Extract date features
data["Journey_Day"] = data["Date_of_Journey"].dt.day
data["Journey_Month"] = data["Date_of_Journey"].dt.month

# Departure time
data["Dep_Time"] = pd.to_datetime(data["Dep_Time"], format="%H:%M")

data["Departure_Hour"] = data["Dep_Time"].dt.hour
data["Departure_Minute"] = data["Dep_Time"].dt.minute

data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  \
# 0 1900-01-01 22:20:00  01:10 22 Mar   2h 50m    non-stop         No info
# 1 1900-01-01 05:50:00         13:15   7h 25m     2 stops         No info
# 2 1900-01-01 09:25:00  04:25 10 Jun      19h     2 stops         No info
# 3 1900-01-01 18:05:00         23:30   5h 25m      1 stop         No info
# 4 1900-01-01 16:50:00         21:35   4h 45m      1 stop         No info
#
#    Price  Journey_Month  Journey_Day  Departure_Hour  Departure_Minute
# 0   3897              3           24              22                20
# 1   7662              5            1               5                50
# 2  13882              6            9               9                25
# 3   6218              5           12              18                 5
# 4  13302              3            1              16                50

# %%
# Keep only the time part (HH:MM)
data["Arrival_Time"] = data["Arrival_Time"].str[:5]

# Convert to datetime
data["Arrival_Time"] = pd.to_datetime(
    data["Arrival_Time"],
    format="%H:%M"
)

# Extract hour and minute
data["Arrival_Hour"] = data["Arrival_Time"].dt.hour
data["Arrival_Minute"] = data["Arrival_Time"].dt.minute

# %%
def convert_duration(duration):
    hours = 0
    minutes = 0

    if "h" in duration:
        hours = int(duration.split("h")[0])

    if "m" in duration:
        minutes = int(duration.split("m")[0].split()[-1])

    return hours * 60 + minutes


data["Duration_Minutes"] = data["Duration"].apply(convert_duration)

# %%
data.drop(
    columns=[
        "Date_of_Journey",
        "Dep_Time",
        "Arrival_Time",
        "Duration",
        "Route"
    ],
    inplace=True
)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10463 entries, 0 to 10462
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Airline           10463 non-null  object
#  1   Source            10463 non-null  object
#  2   Destination       10463 non-null  object
#  3   Total_Stops       10463 non-null  object
#  4   Additional_Info   10463 non-null  object
#  5   Price             10463 non-null  int64
#  6   Journey_Month     10463 non-null  int32
#  7   Journey_Day       10463 non-null  int32
#  8   Departure_Hour    10463 non-null  int32
#  9   Departure_Minute  10463 non-null  int32
#  10  Arrival_Hour      10463 non-null  int32
#  11  Arrival_Minute    10463 non-null  int32
#  12  Duration_Minutes  10463 non-null  int64
# dtypes: int32(6), int64(2), object(5)
# memory usage: 817.6+ KB

# %%
# Target
y = data["Price"]

# Features
X = data.drop("Price", axis=1)

X.head()
# Out:
#        Airline    Source Destination Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi    non-stop         No info
# 1    Air India   Kolkata    Banglore     2 stops         No info
# 2  Jet Airways     Delhi      Cochin     2 stops         No info
# 3       IndiGo   Kolkata    Banglore      1 stop         No info
# 4       IndiGo  Banglore   New Delhi      1 stop         No info
#
#    Journey_Month  Journey_Day  Departure_Hour  Departure_Minute  Arrival_Hour  \
# 0              3           24              22                20             1
# 1              5            1               5                50            13
# 2              6            9               9                25             4
# 3              5           12              18                 5            23
# 4              3            1              16                50            21
#
#    Arrival_Minute  Duration_Minutes
# 0              10               170
# 1              15               445
# 2              25              1140
# 3              30               325
# 4              35               285

# %%
categorical_features = [
    "Airline",
    "Source",
    "Destination",
    "Total_Stops",
    "Additional_Info"
]

numerical_features = [
    "Journey_Day",
    "Journey_Month",
    "Departure_Hour",
    "Departure_Minute",
    "Arrival_Hour",
    "Arrival_Minute",
    "Duration_Minutes"
]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            OneHotEncoder(handle_unknown="ignore"),
            categorical_features
        ),
        (
            "num",
            "passthrough",
            numerical_features
        )
    ]
)

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

pipeline = Pipeline(
    steps=[
        ("preprocessor", preprocessor),
        (
            "model",
            RandomForestRegressor(
                n_estimators=100,
                random_state=42
            )
        )
    ]
)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
data.isnull().sum()
# Out:
# Airline             0
# Source              0
# Destination         0
# Total_Stops         0
# Additional_Info     0
# Price               0
# Journey_Month       0
# Journey_Day         0
# Departure_Hour      0
# Departure_Minute    0
# Arrival_Hour        0
# Arrival_Minute      0
# Duration_Minutes    0
# dtype: int64

# %%
data[data.isnull().any(axis=1)].head()
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Total_Stops, Additional_Info, Price, Journey_Month, Journey_Day, Departure_Hour, Departure_Minute, Arrival_Hour, Arrival_Minute, Duration_Minutes]
# Index: []

# %%
df["Arrival_Time"].head(10)
# Out:
# 0    01:10 22 Mar
# 1           13:15
# 2    04:25 10 Jun
# 3           23:30
# 4           21:35
# 5           11:25
# 6    10:25 13 Mar
# 7    05:05 02 Mar
# 8    10:25 13 Mar
# 9           19:15
# Name: Arrival_Time, dtype: object

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Airline', 'Source',
#                                                    'Destination', 'Total_Stops',
#                                                    'Additional_Info']),
#                                                  ('num', 'passthrough',
#                                                   ['Journey_Day',
#                                                    'Journey_Month',
#                                                    'Departure_Hour',
#                                                    'Departure_Minute',
#                                                    'Arrival_Hour',
#                                                    'Arrival_Minute',
#                                                    'Duration_Minutes'])])),
#                 ('model', RandomForestRegressor(random_state=42))])

# %%
from sklearn.metrics import r2_score, mean_absolute_error
import numpy as np

# Predictions
y_pred = pipeline.predict(X_test)

# Metrics
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(np.mean((y_test - y_pred) ** 2))

print(f"R² Score : {r2:.4f}")
print(f"MAE      : ₹{mae:.2f}")
print(f"RMSE     : ₹{rmse:.2f}")
# Out:
# R² Score : 0.8943
# MAE      : ₹658.92
# RMSE     : ₹1484.97

# %%
import joblib

joblib.dump(pipeline, "../Models/flight_price_pipeline.pkl")

print("Pipeline saved successfully!")
# Out:
# Pipeline saved successfully!
